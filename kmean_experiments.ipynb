# %%
from kmeans_experiment import KMeansExperiment
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
from sklearn import datasets
import numpy as np
from sklearn.decomposition import PCA

# %%
iris = datasets.load_iris()
X = iris.data

# %%
pca = PCA(n_components=2, svd_solver='full')
pca.fit(X)
X_T = pca.transform(X)

# %%
from sklearn.preprocessing import QuantileTransformer
rng = np.random.RandomState(0)
qt = QuantileTransformer(n_quantiles=10, random_state=0)
X_T_norm = qt.fit_transform(X_T)

# %%
iris_experiment = KMeansExperiment(X_T_norm, k=4)

# %%
iris_experiment.show_vor()

# %%
iris_experiment.get_furthest_point()
# Out:
# array([1.0, 0.0], dtype=object)

# %%
iris_experiment2 = KMeansExperiment(X_T_norm, k=5)

# %%
k = 6
experiments = []

# %%
iris_experiment2.show_vor()

# %%
iris_experiment.get_score()
# Out:
# 7.354600012395869

# %%
iris_experiment.add_poison(850)

# %%
iris_experiment.get_score()
# Out:
# 108.14013833675672

# %%
iris_experiment.show_poison_line()

# %%
iris_experiment.run_analysis()
